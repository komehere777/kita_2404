# %% [markdown]
# # 1014

# %% [markdown]
# ## **Tesseract OCR**
# - 오픈 소스 OCR(Optical Character Recognition, 광학 문자 인식) 라이브러리로, 이미지나 PDF 파일에서 텍스트를 추출하는 데 사용됩니다. 이 라이브러리는 문자 인식의 정확성과 강력함으로 인해 다양한 애플리케이션에서 널리 사용됩니다. 아래에 Tesseract 라이브러리에 대한 주요 사항을 자세히 설명하겠습니다.
#
# ### 1. **역사 및 배경**
# - **개발 초기**: Tesseract는 1985년에 Hewlett-Packard(HP) 연구소에서 개발되었습니다. 오랜 기간 동안 내부적으로 사용되다가, 2005년에 오픈 소스로 공개되었습니다.
# - **Google 지원**: 2006년에 Google이 Tesseract 프로젝트를 후원하면서 활발히 발전하게 되었고, 현재 Google이 개발을 이어받아 유지하고 있습니다.
#
# ### 2. **기능 및 특징**
# - **광학 문자 인식(OCR)**: Tesseract는 이미지나 스캔한 문서에서 문자를 인식하여 텍스트로 변환하는 OCR 기능을 제공합니다.
# - **다양한 언어 지원**: 100개 이상의 언어를 지원하며, 한국어를 포함한 여러 언어를 인식할 수 있습니다. 사용자 정의 언어 학습을 통해 새 언어를 추가하거나 기존 언어 인식 성능을 개선할 수도 있습니다.
# - **오픈 소스 라이브러리**: GNU GPL(GNU General Public License) 하에서 제공되며, 무료로 사용하고 배포할 수 있습니다.
# - **이미지 전처리**: 이미지의 품질에 따라 다양한 전처리 기술이 사용될 수 있습니다. Tesseract는 이미지에서의 잡음을 줄이고 글자 인식을 향상시키기 위한 여러 이미지 전처리 기술을 지원합니다.
# - **Pytesseract**: Python에서 Tesseract를 사용할 수 있는 래퍼 라이브러리입니다. 이를 통해 Python 코드 내에서 Tesseract의 기능을 쉽게 사용할 수 있습니다.
#
# 한국어와 표는 클로버가 좋음
#
# #### **Python에서 사용하기 (Pytesseract)**
# Pytesseract를 사용하면 Python 코드 내에서 Tesseract의 기능을 사용할 수 있습니다.
# ```python
# from PIL import Image
# import pytesseract
#
# # 이미지 파일 열기
# image = Image.open('input_image.png')
#
# # 이미지에서 텍스트 추출
# text = pytesseract.image_to_string(image, lang='eng')
#
# print(text)
# ```
# - **Pillow 라이브러리**: 이미지 파일을 열고 처리하기 위해 사용됩니다.
# - **`image_to_string()`**: 이미지에서 텍스트를 추출하는 기본 함수입니다.
#
# ### 3. **언어 데이터 파일**
# Tesseract는 언어 인식을 위해 `.traineddata` 파일을 사용합니다. Tesseract 설치 시 기본적으로 여러 언어가 포함되어 있지만, 추가 언어가 필요한 경우 `tessdata` 폴더에 `.traineddata` 파일을 추가로 다운로드하여 넣어야 합니다.
#
# - **언어 데이터 파일 다운로드**: [tesseract-ocr 언어 데이터 GitHub 저장소](https://github.com/tesseract-ocr/tessdata)에서 필요한 언어 데이터를 다운로드할 수 있습니다.
# - **사용 예시**:
#   ```bash
#   tesseract input_image.png output_text -l kor
#   ```
#   위 명령어는 한국어를 인식하기 위해 `kor` 언어 데이터를 사용합니다.
#
# ### 4. **Tesseract의 주요 옵션**
# - **`-l` 옵션**: 사용할 언어를 지정합니다. 예를 들어 `-l eng`는 영어를 의미하며, 여러 언어를 함께 사용할 수도 있습니다(`-l eng+kor`).
# - **`--psm` 옵션**: 페이지 세분화 모드를 지정합니다. Tesseract는 페이지 레이아웃을 어떻게 분석할지에 대한 여러 모드를 제공합니다.
#   - **예시**: `--psm 6`은 "단일 블록의 균일한 텍스트"로 간주하고 인식합니다.
# - **`--oem` 옵션**: OCR 엔진 모드를 설정합니다.
#   - `0`: Legacy 엔진만 사용.
#   - `1`: LSTM 엔진만 사용.
#   - `2`: 두 엔진 혼합 사용.
#   - `3`: 기본 엔진을 자동 선택.
#
# ### 5. **Tesseract의 응용 분야**
# - **문서 디지털화**: 책이나 문서를 디지털 형식으로 변환하여 데이터베이스에 저장할 때 사용됩니다.
# - **명함 인식**: 명함에서 이름, 연락처 등의 정보를 추출하여 자동으로 주소록에 추가하는 데 사용됩니다.
# - **자동화된 데이터 입력**: 서류나 청구서의 데이터를 자동으로 추출하여 데이터베이스에 입력하는 등 수작업을 줄이고 효율성을 높이는 데 활용됩니다.
# - **차량 번호판 인식**: 차량 번호판 이미지에서 번호를 인식하여 교통 관리 시스템에 적용하는 등 실시간 분석에서 사용됩니다.
#
# ### 6. **장점과 단점**
# #### **장점**:
# - **오픈 소스**: 무료로 사용 가능하고, 사용자 정의를 통해 모델 학습 및 개선이 가능합니다.
# - **다양한 언어 지원**: 많은 언어를 지원하고 추가 학습이 가능합니다.
# - **적응성**: 다양한 플랫폼에서 사용할 수 있으며, Python과 같은 언어에서 연동하기도 쉽습니다.
#
# #### **단점**:
# - **정확도**: 이미지 품질이 나쁘거나 복잡한 레이아웃의 경우 인식 정확도가 떨어질 수 있습니다.
# - **글꼴 의존성**: 인식하려는 텍스트의 글꼴이 Tesseract가 학습한 데이터와 많이 다를 경우 오류가 발생할 수 있습니다.
# - **속도**: 대규모 문서나 고해상도 이미지의 경우 처리 속도가 느릴 수 있습니다.
#
# ### 7. **Tesseract 활용 팁**
# - **이미지 전처리**: 이미지의 노이즈를 줄이거나 명확하게 하기 위해 대비 조정, 이진화 등을 통해 OCR 정확도를 높일 수 있습니다.
# - **다양한 라이브러리와의 연동**: OpenCV와 같은 이미지 처리 라이브러리를 함께 사용하여 이미지 전처리 단계를 추가함으로써 인식 성능을 개선할 수 있습니다.

# %%
# !pip install pytesseract -q

# %%
# !tesseract --version
# Out:
# tesseract v5.3.4.20240503
#  leptonica-1.84.1
#   libgif 5.2.1 : libjpeg 8d (libjpeg-turbo 3.0.1) : libpng 1.6.43 : libtiff 4.6.0 : zlib 1.3 : libwebp 1.4.0 : libopenjp2 2.5.2
#  Found AVX512BW
#  Found AVX512F
#  Found AVX512VNNI
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE4.1
#  Found libarchive 3.7.4 zlib/1.3.1 liblzma/5.6.1 bz2lib/1.0.8 liblz4/1.9.4 libzstd/1.5.6
#  Found libcurl/8.7.1 Schannel zlib/1.3.1 brotli/1.1.0 zstd/1.5.6 libidn2/2.3.7 libpsl/0.21.5 libssh2/1.11.0

# %% [markdown]
# ### install language (언어 설치)
#
# Ex) Kor
#
# ```sudo apt-get install tesseract-ocr-kor```
#
# EX) All languages
#
# ```sudo apt-get install tesseract-ocr-all```

# %%
# !tesseract --list-langs
# Out:
# List of available languages in "C:\Program Files\Tesseract-OCR/tessdata/" (6):
# eng
# jpn
# kor
# osd
# script/Hangul
# script/Japanese

# %% [markdown]
# osd : Orientation and script detection

# %%
# !pip install opencv-python -q

# %%
import cv2
import pytesseract
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r"D:\pythonProject\VISION\ocr_data\ocr_number.png")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# 이미지 표시
plt.imshow(image_rgb)
plt.axis("off")  # 축 숨기기
plt.show()

# %%
image = cv2.imread(r"D:\pythonProject\VISION\ocr_data\ocr_number.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#pytesseract에서는 numpy 배열을 인식하지 못하므로 이미지 파일로 저장해서 파일을 입력해야 인식, os.getpid()는 현재 프로세스 ID를 반환
filename = "{}.jpg".format(os.getpid())
cv2.imwrite(filename, gray)

#이미지를 텍스트로 변환
# 숫자는 lang = None으로 설정, lang = 'eng'으로 설정하면 영어로 인식, lang = 'kor'로 설정하면 한글로 인식

text = pytesseract.image_to_string(Image.open(filename), lang=None)
os.remove(filename)

print(text)
# Out:
# 650 3428

# %%
plt.imshow(gray, cmap="gray")
plt.axis("off")
plt.show()

# %%
filepath = r"D:\pythonProject\VISION\ocr_data\ocr_text.png"

image = cv2.imread(filepath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

filename = "{}.jpg".format(os.getpid())
cv2.imwrite(filename, gray)

text = pytesseract.image_to_string(Image.open(filename), lang='eng')
os.remove(filename)

print(text)
# Out:
# 1.1 Whatis computer vision?
#
# As humans, we perceive the three-dimensional Structure of the world around us with apparent
# case. Think of how vivid the three-dimensional percept is when you look at a vase of flowers
# sitting on the table next to you. You can tell the shape and translucency of each petal through
# the subtle patterns of light and shading that play across its surface and effortlessly segment
# each flower from the background of the scene (Figure 1.1). Looking at a framed group por-
# trait, you can easily count (and name) all of the people in the picture and even guess at their
# emotions from their facial appearance, Perceptual psychologists have spent decades trying to
# understand how the visual system works and, even though they can devise optical illusions
#
# to tease apart some of its principles (Figure 1.3), a complete solution to this puzzle remains
# elusive (Marr 1982; Palmer 1999; Livingstone 2008)

# %% [markdown]
# 이미지를 불러오는 다양한 방법
#
# requests를 이용하여 cv2로 이미지 불러오기

# %%
import requests
import numpy as np

url = "https://user-images.githubusercontent.com/69428232/148318703-ef6bd43f-ec4f-42f5-a336-3b584a662982.jpg"

image_nparray = np.asarray(bytearray(requests.get(url).content), dtype=np.uint8)
org_image = cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)
plt.imshow(org_image)
plt.axis("off")
plt.show()

# %%
import requests
from PIL import Image
from io import BytesIO

response = requests.get(url)
#BytesIO를 사용하여 이미지를 메모리에 로드
#바이트 데이터를 파일 객체로 변환하여 PIL 이미지로 읽어들임
image = Image.open(BytesIO(response.content))

plt.imshow(image)
plt.axis("off")
plt.show()

# %% [markdown]
# imageio를 이용하여 이미지 불러오기

# %% [markdown]
# - OpenCV는 기본적으로 BGR 색상 체계를 사용. imageio.imread로 읽은 이미지는 RGB 색상 체계를 사용하므로, OpenCV에서 처리하기 전에 BGR로 변환하는 것이 일반적인 관행.
# - OCR 처리를 위해서는 추가적으로 그레이스케일로 변환하는 것이 좋으며, 이는 cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)를 사용하여 수행할 수 있다.
# - OCR을 위한 최적의 성능을 원한다면, BGR에서 그레이스케일로의 변환 단계를 추가하는 것이 좋다.

# %%
import imageio

url = "https://user-images.githubusercontent.com/69428232/148318703-ef6bd43f-ec4f-42f5-a336-3b584a662982.jpg"
img = imageio.imread(url)
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# C:\Users\komeh\AppData\Local\Temp\ipykernel_40488\3146116781.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(url)

# %%
img = imageio.imread(url) # read as RGB
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# C:\Users\komeh\AppData\Local\Temp\ipykernel_40488\1597110520.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(url)

# %% [markdown]
# 한글 , 영문, 숫자 혼합 이미지

# %%
import imageio.v2 as imageio

img = imageio.imread(url)
image = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

text = pytesseract.image_to_string(gray, lang='eng+kor')
print(text)
# Out:
# 김 윤 웅
#
# Kim Yunwoong
#
# 0123456789#$

# %% [markdown]
# 음영과 노이즈가 존재하는 경우

# %%
import requests
from io import BytesIO

url = "https://user-images.githubusercontent.com/69428232/148330274-237d9b23-4a79-4416-8ef1-bb7b2b52edc4.jpg"

response = requests.get(url)
image = Image.open(BytesIO(response.content))
plt.figure(figsize=(10, 10))
plt.imshow(image)

plt.axis("off")
plt.show()

# %%
image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

text = pytesseract.image_to_string(gray, lang='eng')

print(text)
# Out:
# WHOLE FOODS MARKET ~ WESTPORT CT 06880
# DW - (203) 221-6858
#
# 399 POST RD WEST
#
# BACON LS NP
# paAcoN LS NP
# BACON LS NP
#
# BROTH CHIC NP

# %% [markdown]
# 이미지 전처리 방법
#
# - 이미지 이진화
# - 이미지 노이즈 제거
# - 이미지 크기 조정

# %%
import numpy as np

url = "https://user-images.githubusercontent.com/69428232/148330274-237d9b23-4a79-4416-8ef1-bb7b2b52edc4.jpg"

image_nparray = np.asarray(bytearray(requests.get(url).content), dtype=np.uint8)
org_image = cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)
rgb_image = cv2.cvtColor(org_image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.subplot(1,1,1)
plt.imshow(rgb_image)
plt.axis("off")
plt.show()

# %%
text = pytesseract.image_to_string(rgb_image, lang='eng')
print(text)
# Out:
# y - wesTPoRT, CT 06880
#
# yHOLE FOODS MARKE
# 399 post RD WEST ~ ;
#
# 903) 227-6858
#
# BACON LS NP
# pacon LS N
#
# BACON LS NP
# pacon tS X
#
# 365

# %% [markdown]
# 전처리하여 수행

# %%
# !pip install imutils
# Out:
# ERROR: Could not find a version that satisfies the requirement imtuils (from versions: none)
# ERROR: No matching distribution found for imtuils

# %%
from imutils.perspective import four_point_transform
import imutils

# %%
def plt_imshow(title='image', image=None, figsize=(10, 6)):
    plt.figure(figsize=figsize)
    
    if type(img) == list:
        if type(title) == list:
           titles = title
        else:
            titles = []
            for i in range(len(img)):
                titles.append(title)
        
        for i in range(len(img)):
            if len(img[i].shape) <=2:
                rgbimg = cv2.cvtColor(img[i], cv2.COLOR_GRAY2RGB)
            else:
                rgbimg = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)
                
            plt.subplot(1, len(img), i+1) 
            plt.imshow(rgbimg)
            plt.title(titles[i])
            plt.xticks([]), plt.yticks([])
        plt.show()
        
    else:
        if len(img.shape) < 3:
            rgbimg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        else:
            rgbimg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(rgbimg)
        plt.title(title)
        plt.axis('off')
        plt.show()

# %%
# 제목(title), 이미지(img), 그리고 이미지를 표시할 때 사용할 그림 크기(figsize)를 매개변수로 받는다.
def plt_imshow(title="image", img=None, figsize=(12, 8)):
    plt.figure(figsize=figsize)

    if type(img) == list:
        if type(title) == list:
            titles = title
        else:
            titles = []

            for i in range(len(img)):
                titles.append(title)

        for i in range(len(img)):
            if len(img[i].shape) <= 2:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_GRAY2RGB)
            else:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)

            plt.subplot(1, len(img), i + 1), plt.imshow(rgbImg)
            plt.title(titles[i])
            plt.xticks([]), plt.yticks([])

        plt.show()
    else:  # 매개변수가 리스트가 아닌 경우
        if len(img.shape) < 3:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        else:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.imshow(rgbImg)
        plt.title(title)
        plt.xticks([]), plt.yticks([])
        plt.show()

# %%
url = "https://user-images.githubusercontent.com/69428232/148330274-237d9b23-4a79-4416-8ef1-bb7b2b52edc4.jpg"

image_nparray = np.asarray(bytearray(requests.get(url).content), dtype=np.uint8)
org_image = cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)
plt_imshow("original image",org_image)

# %%
image = org_image.copy()
image = imutils.resize(image, width=500)
ratio = image.shape[1] / float(image.shape[1])

# 모서리 검출을 위한 전처리

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# 가우시안 블러로 노이즈 제거 (5, 5)는 커널 크기
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
# 케니 엣지 검출기로 경계 검출, 이중 임계값을 사용하여 강한 경계와 약한 경계를 구분,75:최소 임계값, 200:최대 임계값
edged = cv2.Canny(blurred, 75, 200)
plt_imshow(['gray', 'blurred', 'edged'], [gray, blurred, edged])

# %%
# 캐니 가장자리 검출기로 경계 검출
# 함수는 이미지에서 윤곽을 찾아 리스트로 반환
# RETR_EXTERNAL: 가장 바깥쪽 윤곽선만 찾기, CHAIN_APPROX_SIMPLE: 윤곽선을 그릴 수 있는 포인트만 반환
cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
cnts = sorted(cnts, key=cv2.contourArea, reverse=True)

receiptCnt = None # 영수증 윤곽선

for c in cnts:
    # 근사값으로 윤곽선을 단순화
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)

    # 윤곽선이 4개의 꼭지점을 가지고 있으면 종이로 가정
    if len(approx) == 4:
        receiptCnt = approx
        break
    
if receiptCnt is None:
    raise Exception("영수증을 찾을 수 없습니다.")

output = image.copy()
cv2.drawContours(output, [receiptCnt], -1, (0, 255, 0), 2) # 초록색으로 윤곽선 그리기 bgr, 두께 2
plt_imshow("output", output)

# %%
from imutils.perspective import four_point_transform

# four_point_transform 함수는 이미지의 특정 영역을 네 개의 점을 사용하여 변환
receipt = four_point_transform(image, receiptCnt.reshape(4, 2) * ratio) # 원본 이미지에서 영수증 영역을 추출하고 변환
plt_imshow("receipt", receipt)

# %% [markdown]
# options = "--psm 4":
#
# - --psm은 Tesseract의 페이지 분할 모드(Page Segmentation Mode) 옵션입니다.
# - psm 4는 Tesseract에 이미지가 "변수 크기의 텍스트를 포함하는 단일 열"로 구성되어 있다고 알려주는 모드입니다.
# - Tesseract에는 여러 가지 psm 모드가 있는데, 4는 텍스트의 레이아웃이 하나의 열로 구성된 경우에 적합합니다.
#   - psm 3: 자동 페이지 세그멘테이션. OCR 기본 모드입니다.
#   - psm 6: 단락 텍스트를 인식하는 모드입니다.
# - psm 모드를 적절히 설정하는 것은 이미지에 있는 텍스트의 구조에 맞춰 OCR의 성능을 개선할 수 있습니다.

# %%
options = "--psm 4" # tessract에게 이미지가 변수 크기의 텍스트를 포함하는 단일 열로 구성되어 있음을 알려주는 모드
text = pytesseract.image_to_string(cv2.cvtColor(receipt, cv2.COLOR_BGR2GRAY), config=options)
print(text)
# Out:
# WHOLE
# FOODS
#
# ous FOODS MMRKET ~ VESTPORT.CT 06880
# 399 Post RD GEST ~ (208) 227-6458
#
# Ses BACON LS NP 4.99
#
# 365 BACON LS. MP 4.99
# 365 BACON LS NP 4.99
# 365 BACON LS NP 4.99
# BROTH CHIC NP 2.19
#
# FLOUR, ALNOMDOAB 11.99
#
# CHEN BRST BMLSS SK MP 18 80
# HEAVY CREAM NP 3.39
# RLSM REDUCT WP 6.49
# BEEF GAND 88/15 Xr 8.04
# JUICE COF cASHEU © We (8.99
# DOCS PINT ORGANIC WP 14.49)
# WHY ALMOND BUTTER NP 9.99
# TAK 00 BAL 11.33
