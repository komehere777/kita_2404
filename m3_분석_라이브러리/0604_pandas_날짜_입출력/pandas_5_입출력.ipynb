# %% [markdown]
# #0604

# %% [markdown]
# # Contents
#
#
# ---
#
#
#
# *   csv
# *   json
# *   excel

# %%
# csv 파일 읽고 저장하기
import numpy as np
import pandas as pd
ar1 = np.arange(10).reshape(2,5)
df = pd.DataFrame(ar1,columns=list('abcde'))
df.to_csv('test.csv')  #데이터 프레임 저장

# %%
df

# %%
# !ls
# Out:
# sample_data  test.csv

# %%
df = pd.read_csv('test.csv', index_col=0)
df
# Out:
#    a  b  c  d  e
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
df = pd.read_csv('test.csv')  #파일에 있는 인덱스가 컬럼으로 올라감
df
# Out:
#    Unnamed: 0  a  b  c  d  e
# 0           0  0  1  2  3  4
# 1           1  5  6  7  8  9

# %%
# csv 파일 읽고 저장하기
import numpy as np
import pandas as pd
ar1 = np.arange(10).reshape(2,5)
df = pd.DataFrame(ar1,columns=list('abcde'))
df.to_csv('test.csv', index=None)  #데이터 프레임 저장, Unnamed 생성되는거 막기 위해

# %%
df = pd.read_csv('test.csv')
df
# Out:
#    a  b  c  d  e
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
df1 = df.copy()
df1.to_csv('test1.csv')
df1 = pd.read_csv('test1.csv', index_col=0)
df1
# Out:
#    a  b  c  d  e
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
df1.iloc[0] = 2
df1.iloc[1] = 3
df1
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %%
#json 파일 읽고 쓰기
df1.to_json('test2.json')
df_j = pd.read_json('test2.json')
df_j
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %%
#바이너리 파일 읽고 쓰기 - 임시저장시 사용, 속도 빠름
df1.to_pickle('test3.pkl')
df1 = pd.read_pickle('test3.pkl')
df1
# Out:
#    a  b  c  d  e
# 0  2  2  2  2  2
# 1  3  3  3  3  3

# %% [markdown]
# Q.간단한 데이터프레임 작성후 csv, json, pickle형태로 저장후 다시 불러와서 출력하세요.

# %%
timedelta_range = pd.timedelta_range(start=0, end='10D',freq='18H')
li = []
for timedelta in timedelta_range:
    li.append(timedelta.total_seconds()/3600)

df = pd.DataFrame({
    'timedelta': timedelta_range,
    '하루18시간 공부': li
})
df1 = df
#csv로 저장
df1.to_csv('time.csv', index=None)

# %%
# !ls
# Out:
# auto-mpg.xlsx  test1.csv   test3.pkl  time.csv	 time.pkl
# sample_data    test2.json  test.csv   time.json

# %%
#read csv
df1 = pd.read_csv('time.csv')
df1
# Out:
#           timedelta  하루18시간 공부
# 0   0 days 00:00:00        0.0
# 1   0 days 18:00:00       18.0
# 2   1 days 12:00:00       36.0
# 3   2 days 06:00:00       54.0
# 4   3 days 00:00:00       72.0
# 5   3 days 18:00:00       90.0
# 6   4 days 12:00:00      108.0
# 7   5 days 06:00:00      126.0
# 8   6 days 00:00:00      144.0
# 9   6 days 18:00:00      162.0
# 10  7 days 12:00:00      180.0
# 11  8 days 06:00:00      198.0
# 12  9 days 00:00:00      216.0
# 13  9 days 18:00:00      234.0

# %%
#json 파일 만들기
df1.to_json('time.json')

# %%
# !ls
# Out:
# auto-mpg.xlsx  test1.csv   test3.pkl  time.csv	 time.pkl
# sample_data    test2.json  test.csv   time.json

# %%
#read json
df_j = pd.read_json('time.json')
df_j
# Out:
#           timedelta  cumulative_time
# 0   0 days 00:00:00                0
# 1   0 days 18:00:00               18
# 2   1 days 12:00:00               36
# 3   2 days 06:00:00               54
# 4   3 days 00:00:00               72
# 5   3 days 18:00:00               90
# 6   4 days 12:00:00              108
# 7   5 days 06:00:00              126
# 8   6 days 00:00:00              144
# 9   6 days 18:00:00              162
# 10  7 days 12:00:00              180
# 11  8 days 06:00:00              198
# 12  9 days 00:00:00              216
# 13  9 days 18:00:00              234

# %%
#make pickle file
df1.to_pickle('time.pkl')

# %%
# !ls
# Out:
# auto-mpg.xlsx  test1.csv   test3.pkl  time.csv	 time.pkl
# sample_data    test2.json  test.csv   time.json

# %%
#read pickle
df1 = pd.read_pickle('time.pkl')
df1
# Out:
#           timedelta  cumulative_time
# 0   0 days 00:00:00              0.0
# 1   0 days 18:00:00             18.0
# 2   1 days 12:00:00             36.0
# 3   2 days 06:00:00             54.0
# 4   3 days 00:00:00             72.0
# 5   3 days 18:00:00             90.0
# 6   4 days 12:00:00            108.0
# 7   5 days 06:00:00            126.0
# 8   6 days 00:00:00            144.0
# 9   6 days 18:00:00            162.0
# 10  7 days 12:00:00            180.0
# 11  8 days 06:00:00            198.0
# 12  9 days 00:00:00            216.0
# 13  9 days 18:00:00            234.0

# %%
# !pip install openpyxl
#!pip install xlrd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6c9f7f47-68c7-4b98-8878-4832ed6ea826" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c9f7f47-68c7-4b98-8878-4832ed6ea826">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# auto-mpg.xlsx  test1.csv   test3.pkl  time.csv	 time.pkl
# sample_data    test2.json  test.csv   time.json

# %%
df = pd.read_excel('auto-mpg.xlsx')
df.head()
# df.to_excel
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.to_excel('test5.xlsx')

# %%
# !ls
# Out:
# auto-mpg.xlsx  test1.csv   test3.pkl   test.csv  time.json
# sample_data    test2.json  test5.xlsx  time.csv  time.pkl

# %%
df = pd.read_excel('test5.xlsx',index_col=0)
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
