# %% [markdown]
# # 0812

# %% [markdown]
# 다음주까지 api배우고, 그 다음에 자연어 처리 나머지 배우기

# %% [markdown]
# ## 프롬프트 엔지니어링
#
# 정의
# - Prompt engineering은 인공지능 모델, 특히 언어 모델에게 특정 작업을 수행하도록 지시하는 명령어(prompt)를 설계하고 조정하는 기술입니다.
# - 사용자는 명확하고 구체적인 질문이나 지시를 통해 모델이 원하는 결과를 생성하도록 유도할 수 있습니다. 이 과정은 자연어 처리에서 중요한 역할을 하며, 모델의 출력을 최적화하고 정확도를 높이는 데 기여합니다.
#
# 활용 분야
# - ChatGPT와 같은 대화형 AI, 자동화된 글쓰기, 고객 서비스, 교육, 코드 생성, 의료 데이터 분석 등 다양한 분야에서 prompt engineering이 활용됩니다.
# - 이를 통해 AI가 특정 요구 사항에 맞춘 결과를 생성하도록 하여, 작업 효율성을 높이고 사용자 경험을 향상시킬 수 있습니다.
#
# 사례들은 대규모 언어 모델(LLM)을 활용하는 다양한 방법을 보여줍니다. 각 사례는 특정 작업에 맞게 프롬프트를 설계하여 모델이 어떻게 유용한 결과를 생성하는지 설명합니다.
#
# - 텍스트 생성: 창의적인 글쓰기, 마케팅 카피 작성, 기술 문서 생성 등 다양한 분야에서 사용됩니다. 프롬프트의 구체성과 맥락 설정에 따라 생성되는 텍스트의 품질이 달라집니다.
#
# - 코드 생성 및 보완: 개발자가 원하는 코드 스니펫을 생성하거나 오류를 수정하는 데 도움을 줍니다. 예를 들어, 특정 함수나 알고리즘을 구현할 때 LLM을 활용해 코드를 제안받을 수 있습니다.
#
# - 데이터 분석 및 요약: 대량의 데이터를 요약하거나 분석 결과를 해석하는 데 유용합니다. LLM을 통해 데이터를 자연어로 쉽게 설명할 수 있어, 비전문가도 결과를 이해하기 쉽게 만듭니다.
#
# - 교육 및 학습 지원: 특정 주제에 대한 설명을 제공하거나, 학습 문제를 풀 때 힌트를 제시하는 방식으로 활용됩니다. 이는 교육용 도구나 학습 지원 시스템에서 유용하게 쓰일 수 있습니다.
#
# - 대화형 응용: 고객 서비스, 개인 비서 역할을 하는 챗봇 등에서 LLM이 활용됩니다. 사용자의 질문에 대해 신속하고 정확한 답변을 제공하며, 자연스러운 대화를 통해 사용자 경험을 향상시킵니다. - 프로젝트에서 가장 신경을 써야할 부분, 프롬프트를 정교하게 만들어야 한다.
#
# - 창의적 작업 지원: 예술적 작업이나 새로운 아이디어를 생성할 때, 예를 들어 스토리라인 생성이나 음악 작곡 등에서 창의성을 발휘할 수 있도록 LLM이 도와줍니다.

# %% [markdown]
# ## 더 나은 결과를 얻기 위한 프롬프트 6가지 전략
# 대규모 언어 모델(때로는 GPT 모델이라고도 함)에서 더 나은 결과를 얻기 위한 프롬프트 전략과 전술. 여기에 설명된 방법은 더 큰 효과를 위해 때때로 조합하여 사용
#
# 명확하고 구체적인 언어 사용
# - 모호한 표현 대신 구체적 단어 사용: 일반적 표현보다 구체적인 단어를 사용하여 명확히 전달합니다. 예: "빠르다" 대신 "5분 내에".
# - 명확한 문장 구조 유지: 단문을 사용하여 문장이 복잡하지 않도록 합니다.
#
# 단계별 지침 제공
# - 작업 분할: 작업을 여러 단계로 나누어 각 단계를 명확히 설명합니다.
# - 단계별 결과 명시: 각 단계에서 기대되는 결과를 구체적으로 작성합니다.
#
# 필요한 컨텍스트 제공
# - 관련 배경 정보 포함: 작업을 이해하는 데 필요한 배경 정보를 제공합니다.
# - 구체적 시간/상황 명시: 언제 또는 어떤 상황에서 작업이 수행되는지 명시합니다.
#
# 예시 제공
# - 긍정적/부정적 예시 포함: 올바른 예시와 잘못된 예시를 모두 제공하여 비교할 수 있게 합니다.
# - 다양한 시나리오 제시: 다양한 상황에 대한 예시를 포함합니다.
#
# 부가 정보 제공
# - 추가 리소스 링크 제공: 참고할 수 있는 추가 자료나 링크를 제공합니다. - 사이트 주소 줘도 해석 함
# - 참조 자료 목록화: 관련 자료들을 목록으로 정리하여 쉽게 접근할 수 있게 합니다.
#
# 피드백 및 조정
# - 피드백 요청: 지침의 명확성을 확인하기 위해 사용자로부터 피드백을 요청합니다.
# - 지침 조정: 받은 피드백을 반영하여 지침을 수정하고 개선합니다. - 자세하게 요청하려면 1000자 이상으로 요청하면 된다. 목차 넣어서 요청해줘도 좋다

# %% [markdown]
# **명확하고 구체적인 언어 사용**
#
# 모호한 표현 대신 구체적 단어 사용
# - 모호한 표현: "빠르게 제출하세요."
# - 구체적 표현: "5분 내에 제출하세요."
#
# 모호한 표현인 "빠르게"는 사람마다 다르게 해석될 수 있습니다. 어떤 사람에게는 "빠르게"가 1시간을 의미할 수도 있고, 다른 사람에게는 몇 분을 의미할 수도 있습니다. 반면 "5분 내에"는 정확한 시간을 명시하여 모두가 같은 의미로 이해할 수 있게 합니다. 이를 통해 지침의 명확성이 높아져 오해가 줄어들고, 작업이 더 정확하게 수행될 수 있습니다.
#
# **명확한 문장 구조 유지**
# - 복잡한 문장: "프로젝트 파일을 검토하고, 오류를 수정하며, 다음 회의 전에 팀원들과 공유하세요."
# - 단순한 문장: "프로젝트 파일을 검토하세요. 오류를 수정하세요. 다음 회의 전에 팀원들과 공유하세요."
#
# 복잡한 문장은 여러 작업을 한 문장에 포함하여 읽는 사람이 이해하기 어렵게 만듭니다. 단순한 문장은 각 작업을 별도의 문장으로 분리하여 각 지시사항을 명확하게 전달합니다. 이를 통해 독자는 각 작업의 순서와 중요성을 쉽게 파악할 수 있으며, 오해나 실수를 줄일 수 있습니다.
#
# **작업 분할**
# - 복잡한 작업 지시: "보고서를 작성하고 검토한 후, 이메일로 보내세요."
# - 단계별 작업 지시:<br>
#   - 보고서 작성:
#     - 관련 데이터를 수집하세요.
#     - 수집한 데이터를 분석하여 요약하세요.
#     - 분석 결과를 바탕으로 보고서를 작성하세요.
#   - 보고서 검토:
#     - 작성한 보고서를 읽고 오류를 수정하세요.
#     - 팀원에게 보고서를 공유하고 피드백을 받으세요.
#
#   - 이메일로 전송:
#     - 검토한 보고서를 이메일에 첨부하세요.
#     - 적절한 수신자에게 이메일을 보내세요.
#
# 작업을 여러 단계로 분할하면 각 단계의 구체적인 작업이 명확해집니다. 이를 통해 사용자는 각 단계를 하나씩 완료하면서 전체 작업을 체계적으로 수행할 수 있습니다. 작업 분할은 복잡한 작업을 관리 가능하고 이해하기 쉽게 만듭니다.
#
# **단계별 결과 명시**
# - 작업 지시: 보고서를 작성하고 검토한 후, 이메일로 보내세요.
# - 단계별 결과 명시:
#   - 보고서 작성:
#     - 결과: 초안 보고서 완성. 데이터가 정확히 포함되어 있음.
#   - 보고서 검토:
#     - 결과: 오류가 수정된 보고서. 피드백이 반영됨.
#   - 이메일로 전송:
#     - 결과: 보고서가 이메일에 첨부되어 적절한 수신자에게 전송됨.
#
# 각 단계에서 기대되는 결과를 구체적으로 명시하면 사용자가 작업의 목표를 명확히 이해할 수 있습니다. 이를 통해 단계별로 작업의 완성도를 확인할 수 있고, 최종 결과물이 기대에 부합하는지 확인할 수 있습니다. 단계별 결과 명시는 작업의 명확성과 효율성을 높이는 데 중요한 역할을 합니다.
#
# **관련 배경 정보 포함**
# - 지시사항: "지난 주의 프로젝트 파일을 검토하세요."
# - 관련 배경 정보 포함:
#   - 프로젝트 개요:
#     - 배경 정보: "이 프로젝트는 고객 만족도 향상을 목표로 합니다. 지난 주 회의에서 고객 피드백을 분석하고, 이를 반영한 새로운 전략을 논의했습니다."
#   - 특정 파일 지시:
#     - 배경 정보: "지난 주에 작성된 '고객 피드백 분석 보고서'와 '전략 수정 제안서' 파일을 검토하세요. 이 파일들은 프로젝트 폴더의 '2024년 8월' 섹션에 있습니다."
#   - 검토 목적:
#     - 배경 정보: "이번 검토는 제안된 전략이 효과적인지 평가하고, 추가 개선 사항을 도출하는 것을 목표로 합니다."
#
# 작업을 이해하는 데 필요한 배경 정보를 제공하면 사용자가 작업의 목적과 맥락을 명확히 이해할 수 있습니다. 이로 인해 작업 수행의 정확성과 효율성이 높아집니다. 배경 정보는 작업의 중요성, 관련 문서 위치, 수행해야 할 구체적 내용 등을 포함할 수 있습니다.
#
# **구체적 시간/상황 명시**
# - 모호한 지시사항: "회의 전에 보고서를 작성하세요."
# - 구체적 지시사항:
#   - 시간 명시:
#     - 구체적 표현: "월요일 오전 9시 회의 전에 보고서를 작성하세요."
#     - 상황: "회의는 매주 월요일 오전 9시에 시작됩니다. 이 회의에서 이번 주 목표와 작업 분담이 논의될 예정입니다."
#   - 상황 명시:
#     - 구체적 표현: "월간 실적 검토 회의 전에, 이번 달 매출 보고서를 작성하세요."
#     - 상황: "월간 실적 검토 회의는 매월 마지막 금요일 오후 3시에 열립니다. 이 보고서는 전체 팀의 실적을 평가하는 데 사용됩니다."
#
# 구체적인 시간과 상황을 명시하면 작업의 시기와 맥락을 명확히 할 수 있습니다. 이는 사용자가 언제 작업을 완료해야 하는지 정확히 이해하게 하여, 일정 준수와 작업의 적시 수행을 도와줍니다. 또한, 작업의 중요성과 맥락을 이해함으로써, 더 나은 준비와 수행이 가능해집니다.
#
# **긍정적/부정적 예시 포함**
# - 지시사항: "이메일을 작성하세요."
# - 긍정적 예시:
#   - 제목: "회의 일정 확인 요청"
#   - 내용: "안녕하세요, 김 팀장님. 이번 주 금요일 오후 2시에 예정된 회의 일정을 확인하고자 합니다. 참석 가능하신지 알려주시면 감사하겠습니다. 감사합니다. 홍길동 드림."
# - 부정적 예시:
#   - 제목: "회의"
#   - 내용: "안녕하세요, 회의가 이번 주 금요일에 있을 것 같습니다. 참석할 수 있는지 알려주세요. 홍길동."
#
# 긍정적 예시와 부정적 예시를 제공하면 사용자는 무엇이 올바르고 무엇이 잘못된지 명확히 이해할 수 있습니다. 긍정적 예시는 최상의 결과를 보여주어 기대하는 바를 명확히 전달하며, 부정적 예시는 피해야 할 실수를 구체적으로 보여줍니다. 이를 통해 사용자는 지침을 더 잘 따르고, 결과물의 품질을 높일 수 있습니다.
#
# **다양한 시나리오 제시**
# - 지시사항: "보고서를 작성하세요."
# - 다양한 시나리오:
#   - 주간 보고서 작성:
#     - 상황: 매주 금요일마다 주간 업무 요약 보고서를 작성합니다.
#     - 포함 내용: 주요 성과, 문제점, 다음 주 계획.
#     - 긍정적 예시: "이번 주 주요 성과로는 판매 목표 120% 달성이 있습니다. - 문제점으로는 재고 부족이 있었으며, 이를 해결하기 위해 다음 주에는 재고 보충 계획을 세웠습니다."
#     - 부정적 예시: "이번 주에 여러 가지 일이 있었고, 다음 주에도 할 일이 많습니다."
#   - 프로젝트 보고서 작성:
#     - 상황: 프로젝트 마감 시 프로젝트 진행 상황과 결과를 요약한 보고서를 작성합니다.
#     - 포함 내용: 프로젝트 목표, 진행 상황, 최종 결과, 배운 점.
#     - 긍정적 예시: "프로젝트 목표는 고객 만족도 향상이었고, 진행 상황은 계획대로 진행되었습니다. 최종 결과로 고객 만족도가 20% 향상되었습니다. 배운 점은 초기 계획의 중요성입니다."
#     - 부정적 예시: "프로젝트가 끝났고, 결과가 나왔습니다."
#   - 연구 보고서 작성:
#     - 상황: 연구 프로젝트의 결과를 발표하기 위한 보고서를 작성합니다.
#     - 포함 내용: 연구 목적, 방법, 결과, 결론.
#     - 긍정적 예시: "연구 목적은 새로운 항생제의 효과를 검증하는 것이었습니다. 실험 방법은 무작위 대조 실험이었고, 결과는 긍정적이었습니다. 결론은 새로운 항생제가 효과적이라는 것입니다."
#     - 부정적 예시: "연구를 했고, 결과가 좋았습니다."
#
# 다양한 시나리오를 제시하면 사용자는 각 상황에 맞게 작업을 어떻게 수행해야 하는지 명확히 이해할 수 있습니다. 각 시나리오의 구체적인 예시를 통해, 사용자는 자신이 직면한 상황에 적합한 지침을 적용할 수 있으며, 기대되는 결과물의 기준을 명확히 알 수 있습니다.
#
# **추가 리소스 링크 제공 및 참조 자료 목록화**
# - 지시사항: "보고서를 작성하기 위한 참고 자료를 확인하세요."
# - 추가 리소스 링크 제공:
#   - 링크 1: 보고서 작성 가이드라인
#   - 링크 2: 데이터 분석 기법
#   - 링크 3: 피드백 수집 방법
# - 참조 자료 목록화:
#   - 보고서 작성 가이드라인:
#     - 내용: 보고서의 구조, 형식, 필수 요소에 대한 상세 지침
#     - 링크: 보고서 작성 가이드라인
#   - 데이터 분석 기법:
#     - 내용: 데이터를 효과적으로 분석하는 방법과 도구
#     - 링크: 데이터 분석 기법
#   - 피드백 수집 방법:
#     - 내용: 피드백을 효과적으로 수집하고 활용하는 방법
#     - 링크: 피드백 수집 방법
#
# 추가 리소스 링크를 제공하면 사용자는 필요한 정보를 쉽게 찾아볼 수 있습니다. 참조 자료를 목록화하면 관련 자료를 체계적으로 정리하여 사용자가 필요할 때 빠르게 접근할 수 있게 도와줍니다. 이는 작업의 정확성과 효율성을 높이는 데 매우 유용합니다.
#
# **피드백 요청**
# - 지시사항: "보고서를 작성한 후, 제출하세요."
# - 피드백 요청 추가:
#   - 초안 제출:
#     - 지시사항: "보고서 초안을 작성한 후, 팀원들에게 공유하세요."
#     - 피드백 요청: "초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요."
#   - 최종본 제출:
#     - 지시사항: "피드백을 반영한 최종 보고서를 작성한 후, 제출하세요."
#     - 피드백 요청: "제출 전, 팀원 또는 관리자에게 최종 확인을 요청하세요. 보고서의 명확성과 완성도를 높이기 위해 피드백을 활용하세요."
#
# 피드백 요청을 통해 지침의 명확성을 확인하고 개선할 수 있습니다. 사용자로부터 피드백을 받으면, 지침이 제대로 이해되고 있는지 확인할 수 있으며, 필요한 경우 수정하여 더 명확하고 효과적인 지침을 제공할 수 있습니다. 이를 통해 작업의 품질과 정확성을 높일 수 있습니다.
#
# **지침 조정**
# - 초기 지침:
# "프로젝트 계획서를 작성하세요."
# - 피드백:
#   - "계획서에 포함해야 할 세부 항목이 명확하지 않습니다."
#   - "완료 기한이 명시되지 않아 혼란스럽습니다."
# - 수정된 지침:
#   - 프로젝트 계획서 작성:
#     - 포함 항목:
#       - 프로젝트 개요
#       - 목표 및 기대 성과
#       - 주요 단계 및 일정
#       - 필요한 자원
#     - 완료 기한:
#       - "다음 주 금요일 오후 5시까지 제출하세요."
#
# 피드백을 반영하여 지침을 수정하면, 지침의 명확성과 효과성이 개선됩니다. 사용자가 작업을 더 정확하고 효율적으로 수행할 수 있도록 도와줍니다. 피드백을 통해 지침의 문제점을 파악하고, 구체적이고 명확한 지침으로 수정하는 과정이 중요합니다.
#
#
# 프로젝트 적용시 사용하길

# %%
from openai import OpenAI
import os

client = OpenAI(
)

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[ #few-shot learning
        {"role": "system", "content": "당신은 ai 모델 개발자이다."},
        
        {"role": "user", "content": "LLM에 대해 설명해줘."},
    ]
)

print(completion.choices[0].message.content)
# Out:
# LLM은 "Large Language Model"의 약자로, 대규모 언어 모델을 의미합니다. 이러한 모델은 방대한 양의 텍스트 데이터를 기반으로 학습하여, 언어 이해와 생성 기능을 갖춘 인공지능 시스템입니다. LLM은 자연어 처리(NLP) 분야에서 중요한 역할을 하며, 다양한 작업을 수행할 수 있습니다. 주요 특징은 다음과 같습니다:
#
# 1. **대규모 데이터 학습**: LLM은 수십억에서 수조 개의 단어로 구성된 데이터셋에서 학습합니다. 이는 모델이 다양한 주제, 문체 및 문맥을 이해할 수 있도록 합니다.
#
# 2. **Transformer 아키텍처**: 대부분의 최신 LLM은 Transformer 아키텍처를 기반으로 합니다. 이 아키텍처는 Attention Mechanism을 사용하여 입력 문장 내에서 단어 간의 관계를 효과적으로 모델링합니다.
#
# 3. **언어 생성 및 이해**: LLM은 주어진 입력에 대해 자연스러운 언어로 텍스트를 생성하거나 질문에 답변하는 등의 작업을 수행할 수 있습니다. 예를 들어, 문서 요약, 번역, 대화 생성 등 다양한 NLP 작업에 활용됩니다.
#
# 4. **사전 학습 및 미세 조정**: LLM은 대량의 일반 데이터를 통해 사전 학습(pre-training)된 후, 특정 작업에 맞게 추가로 학습(micro-fine-tuning)될 수 있습니다. 이를 통해 모델의 성능을 향상시킬 수 있습니다.
#
# 5. **응용 분야**: LLM은 고객 서비스 챗봇, 콘텐츠 생성, 코드 작성, 교육 도구, 의료 기초 지식 제공 등 여러 분야에서 활용되고 있습니다.
#
# 사례로는 OpenAI의 GPT(Generative Pre-trained Transformer) 시리즈, Google의 BERT, Meta의 LLaMA 등이 있습니다. 이러한 LLM은 지속적으로 발전하고 있으며, 언어 이해의 경계를 확장하고 있습니다.

# %%
from openai import OpenAI
import os

client = OpenAI(
)

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[  # few-shot learning
        {"role": "system", "content": "당신은 ai 모델 개발자이다."},
        {"role": "user", "content": "LLM에 대해 설명해줘."},
    ],
)

print(completion)
# Out:
# ChatCompletion(id='chatcmpl-9vF1EjTI7qRRPYA21jfslll8N0esg', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='LLM은 "대규모 언어 모델" (Large Language Model)의 약자로, 자연어 처리(NLP) 분야에서 사용되는 모델입니다. LLM은 대량의 텍스트 데이터를 기반으로 학습되어, 사람의 언어를 이해하고 생성할 수 있는 능력을 갖추고 있습니다. 이러한 모델은 다양한 작업을 수행할 수 있습니다, 예를 들어:\n\n1. **텍스트 생성**: 주어진 프롬프트에 따라 자연스러운 문장을 생성할 수 있습니다.\n2. **질문 응답**: 사용자의 질문에 대한 답변을 제공할 수 있습니다.\n3. **번역**: 한 언어의 텍스트를 다른 언어로 번역할 수 있습니다.\n4. **요약**: 긴 텍스트를 간단하게 요약할 수 있습니다.\n5. **감정 분석**: 텍스트의 감정을 분석할 수 있습니다.\n\nLLM은 주로 딥러닝 기반 아키텍처, 특히 트랜스포머(Transformer) 아키텍처를 사용하여 구현됩니다. 트랜스포머 아키텍처는 입력 데이터의 다양한 부분 간의 관계를 효과적으로 모델링할 수 있는 강력한 구조입니다.\n\n이러한 모델은 많은 양의 데이터에 대해 사전 훈련(pre-training)을 거친 후, 특정 작업에 맞게 추가 학습(fine-tuning)할 수 있습니다. 대표적인 LLM의 예로는 OpenAI의 GPT(Generative Pre-trained Transformer), Google의 BERT(Bidirectional Encoder Representations from Transformers), Meta의 LLaMA 등이 있습니다.\n\nLLM은 다양한 분야에서 활용되고 있으며, 챗봇, 고객 지원, 콘텐츠 생성, 교육 자료 작성 등 여러 용도로 사용되고 있습니다. 하지만 이러한 모델이 윤리적 문제나 편향적인 결과를 낳을 수 있는 점에 대한 논의도 계속 이루어지고 있습니다.', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1723429456, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_48196bc67a', usage=CompletionUsage(completion_tokens=402, prompt_tokens=28, total_tokens=430))

# %% [markdown]
# 명확성과 구체성
# - 특정 주제에 대해 글을 작성하도록 요청할 때

# %%
from openai import OpenAI
import os

client = OpenAI(
)

prompt = "재생 가능 에너지원이 지구 온나나화를 줄이는 데 기여하는 이점에 대해 간결한 단락으로 설명해 주세요"

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[  # few-shot learning
              {"role": "system", "content": "당신은 환경문제를 연구하는 과학자이다.."},
              {"role": "user", "content": prompt},
    ],
)

print(completion.choices[0].message.content)
# Out:
# 재생 가능 에너지원은 지구 온난화를 줄이는 데 중요한 역할을 합니다. 이들은 태양광, 풍력, 수력, 바이오매스와 같은 자연에서 지속적으로 재생되는 자원을 활용하여 에너지를 생산합니다. 이러한 에너지원은 화석 연료와 달리 이산화탄소와 같은 온실가스를 거의 또는 전혀 배출하지 않아 대기 중 온실가스 농도를 감소시키는 데 기여합니다. 또한, 재생 가능 에너지는 에너지 독립성을 높이고, 환경 파괴를 줄이며, 지속 가능한 발전을 촉진하는 데 기여하는 등 다양한 환경적 이점을 제공합니다. 이로 인해 기후 변화의 영향을 완화하고, 인류와 생태계의 건강을 보호하는 데 중요한 기반이 됩니다.

# %%
prompt = "재생 가능 에너지원이 태양열 전지판의 효율을 모델별로 알려줘"

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[  # few-shot learning
        {"role": "system", "content": "당신은 환경문제를 연구하는 과학자이다.."},
        {"role": "user", "content": prompt},
    ],
)

print(completion.choices[0].message.content)
# Out:
# 태양열 전지판의 효율은 여러 모델과 기술에 따라 달라지며, 일반적으로 다음과 같은 유형의 태양광 패널이 있습니다:
#
# 1. **단결정 실리콘 태양광 패널 (Monocrystalline Silicon)**:
#    - 효율: 약 15% - 22%
#    - 설명: 단결정 실리콘으로 제작되어 높은 효율과 긴 사용 수명을 제공합니다.
#
# 2. **다결정 실리콘 태양광 패널 (Polycrystalline Silicon)**:
#    - 효율: 약 13% - 16%
#    - 설명: 여러 개의 실리콘 결정으로 이루어져 있으며, 단결정 패널에 비해 저렴하지만 효율은 낮습니다.
#
# 3. **박막 태양광 패널 (Thin-Film Solar Cells)**:
#    - 효율: 약 10% - 12% (일부 고급 기술은 13% 이상)
#    - 설명: 아몰퍼스 실리콘, 사파이어, CdTe(카드뮴 텔루라이드) 등으로 만들어지며 가벼운 특성을 가지고 있으나 효율이 낮습니다.
#
# 4. **Bifacial 태양광 패널**:
#    - 효율: 약 15% - 20% (양면에서 태양광을 받아들이므로 전체 에너지 생산이 높음)
#    - 설명: 양면에서 빛을 받아들이는 특성을 가진 패널로, 주로 효율적인 설치 방식과 반사광을 활용합니다.
#
# 5. **고효율 태양광 패널 (High-Efficiency Panels)**:
#    - 효율: 약 22% - 26%
#    - 설명: 변형된 기술(예: PERC, HJT)이나 소재를 사용하여 상용 제품 중 가장 높은 효율을 제공합니다.
#
# 각 모델의 효율은 사용 환경, 지역, 패널 설치 각도 및 기타 변수에 따라 달라질 수 있습니다. 최신 기술 발전에 따라 효율 개선이 이루어지고 있으니, 관련된 최신 정보를 확인하는 것이 좋습니다.

# %% [markdown]
# 맥락 제공
# - 특정 사건에 대한 설명을 요청할 때

# %%
prompt = (
    "다음 맥락을 고려하여 설명해 주세요: '2020년 전 세계적인 팬데믹은 다양한 산업에 큰 혼란을 초래했습니다.'"
    "글로벌 공급망에 미친 영향을 분석해 주세요"
)

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[  # few-shot learning
        {"role": "system", "content": "당신은 경제 전문가이다."},
        {"role": "user", "content": prompt},
    ],
)

print(completion.choices[0].message.content)
# Out:
# 2020년 COVID-19 팬데믹은 글로벌 공급망에 심각한 영향을 미쳤습니다. 다음은 그 주요 요인과 결과입니다.
#
# 1. **생산 중단**: 많은 국가들이 초기 방역 조치를 취하면서 공장들이 폐쇄되거나 운영을 중단했습니다. 이로 인해 원자재와 부품의 생산이 급감하였고, 특히 중국과 같은 제조 중심 국가에서의 생산 차질이 글로벌 공급망에 직접적인 영향을 미쳤습니다.
#
# 2. **물류 지연**: 팬데믹으로 인해 항공편과 해상 운송이 크게 제한되었습니다. 항만의 혼잡과 물류 센터의 운영 문제는 제품과 원자재의 배송 지연을 초래하였고, 이는 각 산업에 걸쳐 공급 부족 현상을 유발했습니다.
#
# 3. **수요 변화**: 팬데믹으로 인해 소비자 행동이 급격히 변화했습니다. 예를 들어, 팬데믹 초기에는 식료품과 가정용품의 수요가 폭증한 반면, 여행 및 외식 산업은 큰 타격을 받았습니다. 이러한 수요 변화는 공급망을 더욱 복잡하게 만들었습니다.
#
# 4. **상호 의존성의 드러남**: 글로벌화된 공급망의 상호 의존성은 팬데믹 동안 더욱 두드러졌습니다. 특정 지역에서의 문제가 전 세계적으로 영향을 미치며, 공급망의 취약성을 드러냈습니다. 예를 들어, 반도체 부족 사태는 자동차 산업과 전자 제품에 광범위한 영향을 미쳤습니다.
#
# 5. **공급망 재편성**: 팬데믹 이후 기업들은 공급망의 리스크를 줄이기 위해 다변화 전략을 모색하고 있습니다. 일부 기업은 단일 공급처에 의존하는 대신, 더 많은 지역에서 공급자를 확보하거나 생산을 재진행하는 방안을 고려하고 있습니다.
#
# 6. **디지털화 및 자동화**: 팬데믹으로 인해 많은 기업이 비대면 거래와 온라인 판매로 전환하면서 공급망의 디지털화 및 자동화가 가속화되었습니다. 이는 정보의 실시간 공유와 효율성을 높여주지만, 동시에 기술적 의존도를 증가시키는 부작용도 발생하였습니다.
#
# 결론적으로, COVID-19 팬데믹은 글로벌 공급망에 구조적인 변화를 요구하게 했으며, 이는 기업들이 대응 전략을 재고하도록 만들었습니다. 앞으로의 공급망은 보다 탄력적이고, 디지털화된 형태로 발전할 가능성이 높습니다.

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY")
)

# %%
client = OpenAI(
)

# %%
prompt = (
    "다음 맥락을 고려하여 설명해 주세요: '2020년 전 세계적인 팬데믹은 다양한 산업에 큰 혼란을 초래했습니다.'"
    "글로벌 공급망에 미친 영향을 분석해 주세요"
)

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[  # few-shot learning
        {"role": "system", "content": "당신은 경제 전문가이다."},
        {"role": "user", "content": prompt},
    ],
)

print(completion.choices[0].message.content)
# Out:
# 2020년의 전 세계적인 팬데믹은 글로벌 공급망에 상당한 영향을 미쳤습니다. 팬데믹으로 인해 여러 산업이 직면한 주요 문제는 다음과 같습니다.
#
# 1. **생산 차질**: 많은 국가가 봉쇄 조치를 시행하면서 공장과 생산 시설이 일시적으로 문을 닫거나 운영을 축소했습니다. 특히 아시아의 주요 제조국에서의 생산 중단은 전 세계적으로 필수 부품과 제품의 공급에 큰 타격을 주었습니다.
#
# 2. **물류와 운송의 혼잡**: 팬데믹으로 인해 해상 및 항공 운송이 제한되면서 물류 체계의 혼잡이 발생했습니다. 항구의 적체와 항공편 감소는 상품이 제때 이동하지 못하게 하여 공급망의 병목 현상을 초래했습니다.
#
# 3. **노동력 부족**: 감염 위험을 줄이기 위해 많은 근로자들이 자가 격리 및 격리 조치를 받으면서 생산성이 감소했습니다. 또한, 일부 지역에서는 노동력이 부족하여 원자재 채굴 및 가공에 지연이 발생했습니다.
#
# 4. **수요 변화**: 팬데믹으로 인해 소비자 행동이 급격하게 변화하면서 특정 산업에 대한 수요가 급증하고, 다른 산업은 위축되었습니다. 예를 들어, 의료 및 기술 제품에 대한 수요는 증가했지만 여행 및 관광 관련 업종은 큰 타격을 받았습니다.
#
# 5. **공급망 재편성과 다변화**: 팬데믹은 공급망의 취약성을 부각시켜 기업들이 공급망 재편성과 다변화를 모색하게 했습니다. 기업들은 특정 지역에 의존하는 것을 줄이고, 대체 공급처를 찾는 경향이 증가했습니다.
#
# 6. **디지털 전환 가속화**: 많은 기업들이 비대면 상태에서 비즈니스를 운영하기 위해 디지털 기술을 도입하게 되었으며, 이는 공급망 관리에도 영향을 미쳤습니다. 실시간 데이터 분석 및 자동화를 통해 운영 효율성을 높이려는 노력이 증가했습니다.
#
# 결론적으로, 2020년 팬데믹은 글로벌 공급망에 심오한 영향을 미쳤으며, 이는 단기적 충격뿐만 아니라 장기적인 변화로 이어지고 있습니다. 기업들은 이러한 경험을 바탕으로 더 유연하고 회복력 있는 공급망을 구축하기 위해 노력하고 있습니다.

# %% [markdown]
# 반복과 테스트
# - 여러 프롬프트를 시도하고, 어떤 프롬프트가 더 나은 결과를 가져오는지 확인할 때

# %%
prompts = [
    "정기적인 운동의 건강상의 이점은 무엇인가요?",
    "정기적으로 운동을 하는 것의 장점을 설명해 주세요.",
    "정기적인 신체 활동이 건강에 어떤 영향을 미치나요?",
]

for prompt in prompts:
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[  # few-shot learning
            {"role": "system", "content": "당신은 운동 전문가이다."},
            {"role": "user", "content": prompt},
        ],
    )

    print(f'프롬프트: {prompt}')
    print(completion.choices[0].message.content)
    print("\n"+ "="*100 + "\n")
# Out:
# 프롬프트: 정기적인 운동의 건강상의 이점은 무엇인가요?
# 정기적인 운동은 신체적, 정신적 건강에 많은 이점을 제공합니다. 다음은 주요 이점입니다:
#
# 1. **체중 관리**: 운동은 칼로리를 소모하고 체중을 유지하는 데 도움을 줍니다.
#
# 2. **심혈관 건강 개선**: 규칙적인 유산소 운동은 심장과 혈관의 기능을 향상시키고, 심장병 및 고혈압의 위험을 감소시킵니다.
#
# 3. **근육과 뼈 강화**: 저항 운동은 근육을 강화하고 뼈 밀도를 증가시켜 골다공증의 위험을 줄입니다.
#
# 4. **정신 건강 향상**: 운동은 스트레스 감소, 불안 완화, 우울증 예방에 도움을 주며 전반적인 기분을 개선합니다.
#
# 5. **면역력 증진**: 규칙적인 운동은 면역 체계를 강화하여 감염과 질병에 대한 저항력을 높입니다.
#
# 6. **에너지 수준 증가**: 운동은 신진대사를 촉진하고 에너지를 증가시켜 일상 생활에 활력을 더합니다.
#
# 7. **수면 질 향상**: 규칙적인 신체 활동은 수면의 질을 개선하고 불면증을 줄이는 데 도움을 줄 수 있습니다.
#
# 8. **세포 노화 지연**: 운동은 세포의 노화를 늦추고 전반적인 건강을 유지하는 데 기여합니다.
#
# 9. **인지 기능 개선**: 운동은 뇌 건강에 긍정적인 영향을 미치고 기억력, 집중력, 문제 해결 능력을 향상시킬 수 있습니다.
#
# 10. **사회적 상호작용**: 운동은 친구나 가족과 함께 할 수 있는 활동으로, 사회적 유대감을 강화하는 데 도움을 줍니다.
#
# 이러한 건강상의 이점을 통해 정기적인 운동은 전반적인 삶의 질을 높이는 데 중요한 역할을 합니다.
#
# ====================================================================================================
#
# 프롬프트: 정기적으로 운동을 하는 것의 장점을 설명해 주세요.
# 정기적으로 운동을 하는 것은 신체적, 정신적, 정서적 건강에 많은 장점을 제공합니다. 다음은 그 몇 가지 주요 이점입니다:
#
# 1. **신체 건강 증진**:
#    - **체중 관리**: 운동은 칼로리를 소모하고 체지방을 줄이는 데 도움을 주어 적정 체중을 유지하는 데 기여합니다.
#    - **심혈관 건강**: 규칙적인 유산소 운동은 심장과 혈관의 기능을 개선하고 심장병의 위험을 줄여줍니다.
#    - **근육과 뼈의 강화**: 힘 훈련은 근육과 뼈의 밀도를 향상시켜 골절 위험을 줄이고 근력을 증가시킵니다.
#
# 2. **정신적 이점**:
#    - **스트레스 감소**: 운동은 스트레스 호르몬을 낮추고, 엔돌핀과 같은 기분 좋은 호르몬을 방출하여 스트레스를 줄이는 데 효과적입니다.
#    - **우울증과 불안의 감소**: 규칙적인 신체 활동은 우울증 증상을 완화하고 불안감을 줄이는 데 도움을 줄 수 있습니다.
#    - **인지 기능 향상**: 운동은 뇌의 혈류를 증가시켜 기억력과 집중력을 향상시키는 데 기여합니다.
#
# 3. **정서적 안정**:
#    - **자신감 증가**: 운동을 통해 몸매가 좋아지고 건강이 향상되면서 자신감이 증가할 수 있습니다.
#    - **사회적 관계 형성**: 팀 스포츠나 그룹 운동은 사회적 상호작용을 촉진하여 소속감을 느끼게 해줍니다.
#
# 4. **수면 개선**:
#    - 운동은 깊은 잠을 촉진하고 수면의 질을 향상시킵니다. 규칙적인 신체 활동은 잠드는 시간을 단축시키고, 전체적인 수면 패턴을 개선하는 데 도움이 됩니다.
#
# 5. **노화 방지 효과**:
#    - 지속적인 운동은 노화 과정을 늦추고, 관절과 근육의 유연성을 유지하며, 불균형으로 인한 낙상의 위험을 줄이는데 기여합니다.
#
# 이 모든 이점들은 개인의 생활 방식, 운동의 종류 및 강도에 따라 달라질 수 있지만, 전반적으로 정기적인 운동은 건강을 유지하고 삶의 질을 향상시키는 중요한 요소입니다.
#
# ====================================================================================================
#
# 프롬프트: 정기적인 신체 활동이 건강에 어떤 영향을 미치나요?
# 정기적인 신체 활동은 건강에 여러 가지 긍정적인 영향을 미칩니다. 다음은 주요한 몇 가지 효과입니다:
#
# 1. **심혈관 건강 개선**: 규칙적인 운동은 심장과 혈관의 기능을 강화하고, 혈압을 낮추며, 콜레스테롤 수치를 개선합니다.
#
# 2. **체중 관리**: 신체 활동은 칼로리를 소모하게 하여 체중을 조절하는 데 도움을 줍니다. 적절한 신체 활동은 비만 예방에 중요한 역할을 합니다.
#
# 3. **근육 및 뼈 건강**: 운동은 근육을 강화하고 뼈의 밀도를 높여 osteoporosis(골다공증)와 같은 질병을 예방하는 데 도움이 됩니다.
#
# 4. **정신 건강 증진**: 신체 활동은 스트레스와 불안을 줄이고, 우울증을 완화시키며, 전반적인 기분을 좋게 하는 데 기여합니다. 이는 엔도르핀과 같은 긍정적인 화학물질의 분비를 촉진하기 때문입니다.
#
# 5. **면역 체계 강화**: 규칙적인 운동은 면역 기능을 강화하여 감염에 대한 저항력을 높이고, 전체적인 건강을 개선합니다.
#
# 6. **체력 향상**: 꾸준한 신체 활동은 지구력, 근력, 유연성을 향상시키고, 일상 생활에서의 활동성을 증가시킵니다.
#
# 7. **수면 개선**: 적절한 운동은 수면의 질을 향상시킬 수 있으며, 수면 장애가 있는 사람들에게 도움이 될 수 있습니다.
#
# 8. **만성 질환 예방**: 운동은 제2형 당뇨병, 심장병, 특정 종류의 암 등 만성 질환의 위험을 감소시키는 데 중요한 역할을 합니다.
#
# 9. **사회적 상호작용**: 운동을 통해 친구나 가족과 함께 활동하면 사회적 유대감이 강화되고 긍정적인 관계를 형성하는 데 도움이 됩니다.
#
# 이러한 이점을 얻으려면, 세계보건기구(WHO)의 권장 사항에 따라 적어도 주 150분의 중강도 유산소 운동을 하는 것이 좋습니다. 추가로 근력 운동도 주기를 두고 포함시키는 것이 이상적입니다.
#
# ====================================================================================================
